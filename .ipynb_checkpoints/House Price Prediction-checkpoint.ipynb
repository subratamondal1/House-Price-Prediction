# %% [markdown]
# # <center>House Price Prediction</center>

# %%
# import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns
import statsmodels.formula.api as smf
import statsmodels.graphics.api as smg
import patsy
# %matplotlib inline

from statsmodels.graphics.correlation import plot_corr
from sklearn.model_selection import train_test_split

# %% [markdown]
# # LOAD DATA

# %%
# load data
df = pd.read_excel("data/assignment1.xlsx")

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
# inspect the first five rows
df.head()
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
# 2       2013.583333       13.3                                 561.98450
# 3       2013.500000       13.3                                 561.98450
# 4       2012.833333        5.0                                 390.56840
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
# 2                             5  24.98746  121.54391                   3
# 3                             5  24.98746  121.54391                   2
# 4                             5  24.97937  121.54245                   1
#
#    House size (sqft)  House price of unit area
# ...

# %%
# check no. of rows by columns
df.shape
# Out:
# (414, 9)

# %%
# check missing values
df.isnull().sum()
# Out:
# Transaction date                            0
# House Age                                   0
# Distance from nearest Metro station (km)    0
# Number of convenience stores                0
# latitude                                    0
# longitude                                   0
# Number of bedrooms                          0
# House size (sqft)                           0
# House price of unit area                    0
# dtype: int64

# %%
# drop duplicate values
df = df.drop_duplicates()
df.shape
# Out:
# (414, 9)

# %% [markdown]
# #### NOTES
# 1. **No missing values**
# 2. **No duplicate values**

# %%
list(df.columns)
# Out:
# ['Transaction date',
#  'House Age',
#  'Distance from nearest Metro station (km)',
#  'Number of convenience stores',
#  'latitude',
#  'longitude',
#  'Number of bedrooms',
#  'House size (sqft)',
#  'House price of unit area']

# %%
# inspect datatypes
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 414 entries, 0 to 413
# Data columns (total 9 columns):
#  #   Column                                    Non-Null Count  Dtype
# ---  ------                                    --------------  -----
#  0   Transaction date                          414 non-null    float64
#  1   House Age                                 414 non-null    float64
#  2   Distance from nearest Metro station (km)  414 non-null    float64
#  3   Number of convenience stores              414 non-null    int64
#  4   latitude                                  414 non-null    float64
#  5   longitude                                 414 non-null    float64
#  6   Number of bedrooms                        414 non-null    int64
#  7   House size (sqft)                         414 non-null    int64
#  8   House price of unit area                  414 non-null    float64
# dtypes: float64(6), int64(3)
# memory usage: 32.3 KB

# %%
# basic statistics of the data
df.describe().T
# Out:
#                                           count         mean          std  \
# Transaction date                          414.0  2013.148953     0.281995
# House Age                                 414.0    17.712560    11.392485
# Distance from nearest Metro station (km)  414.0  1083.885689  1262.109595
# Number of convenience stores              414.0     4.094203     2.945562
# latitude                                  414.0    24.969030     0.012410
# longitude                                 414.0   121.533361     0.015347
# Number of bedrooms                        414.0     1.987923     0.818875
# House size (sqft)                         414.0   931.475845   348.910269
# House price of unit area                  414.0    37.980193    13.606488
#
#                                                   min          25%  \
# Transaction date                          2012.666667  2012.916667
# House Age                                    0.000000     9.025000
# ...

# %%
# splitting data into train & test set
# features | independent variables
X = df.drop("House price of unit area",axis=1)

# target | dependent variable
y = df[["House price of unit area"]]

display(X.head(2))
display(y.head(2))

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2022)

X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
#    Transaction date  House Age  Distance from nearest Metro station (km)  \
# 0       2012.916667       32.0                                  84.87882
# 1       2012.916667       19.5                                 306.59470
#
#    Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 0                            10  24.98298  121.54024                   1
# 1                             9  24.98034  121.53951                   2
#
#    House size (sqft)
# 0                575
# 1               1240
#    House price of unit area
# 0                      37.9
# 1                      42.2
# ((331, 8), (83, 8), (331, 1), (83, 1))

# %%
# train data 
train_data = pd.concat([X_train,y_train], axis = 1)
display(train_data.head())
display(train_data.shape)

# test data
test_data = pd.concat([X_test,y_test],axis=1)
display(test_data.head())
display(test_data.shape)
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 248       2013.000000       19.0                                 1009.2350
# 13        2012.666667       20.4                                 2469.6450
# 199       2013.416667       18.2                                  451.6419
# 391       2013.583333        6.2                                 1939.7490
# 150       2013.250000       35.8                                  170.7311
#
#      Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 248                             0  24.96357  121.54951                   2
# 13                              4  24.96108  121.51046                   3
# 199                             8  24.96945  121.54490                   1
# 391                             1  24.95155  121.55387                   3
# 150                             7  24.96719  121.54269                   1
#
#      House size (sqft)  House price of unit area
# ...

# %%
# correlation matrix
corr_matrix = train_data.corr()
corr_matrix
# Out:
#                                           Transaction date  House Age  \
# Transaction date                                  1.000000   0.064542
# House Age                                         0.064542   1.000000
# Distance from nearest Metro station (km)          0.056316  -0.008027
# Number of convenience stores                      0.012538   0.070825
# latitude                                          0.045157   0.077356
# longitude                                        -0.044492  -0.010438
# Number of bedrooms                                0.049614   0.012472
# House size (sqft)                                 0.054103  -0.026433
# House price of unit area                          0.070544  -0.203824
#
#                                           Distance from nearest Metro station (km)  \
# Transaction date                                                          0.056316
# House Age                                                                -0.008027
# ...

# %%
# heatmap
sns.heatmap(corr_matrix,vmin=-1,vmax=1,annot=True,cmap="RdBu",linewidths=.5,fmt=".2f")
plt.show()

# %%
sns.regplot(data=train_data,x="latitude",y="House price of unit area")
plt.show()

# %%
sns.regplot(data=train_data,x="longitude",y="House price of unit area")
plt.show()

# %%
sns.regplot(data=train_data,x="Number of convenience stores",y="House price of unit area")
plt.show()

# %%
sns.regplot(data=train_data,x="Distance from nearest Metro station (km)",y="House price of unit area")
plt.show()

# %%
train_data.head()
# Out:
#      Transaction date  House Age  Distance from nearest Metro station (km)  \
# 248       2013.000000       19.0                                 1009.2350
# 13        2012.666667       20.4                                 2469.6450
# 199       2013.416667       18.2                                  451.6419
# 391       2013.583333        6.2                                 1939.7490
# 150       2013.250000       35.8                                  170.7311
#
#      Number of convenience stores  latitude  longitude  Number of bedrooms  \
# 248                             0  24.96357  121.54951                   2
# 13                              4  24.96108  121.51046                   3
# 199                             8  24.96945  121.54490                   1
# 391                             1  24.95155  121.55387                   3
# 150                             7  24.96719  121.54269                   1
#
#      House size (sqft)  House price of unit area
# ...
