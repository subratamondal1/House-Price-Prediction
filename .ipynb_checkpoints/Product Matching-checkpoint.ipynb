# %% [markdown]
# # <center>PRODUCT MATCHING</center>

# %%
# importing libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# load amazon dataset
amazon_df = pd.read_csv("data/amazon.csv",encoding= 'unicode_escape')

# load flipkart dataset
flipkart_df = pd.read_csv("data/flipkart.csv",encoding= 'unicode_escape')

# %%
# set index 
amazon_df = amazon_df.set_index("uniq_id")

# %%
# set index
flipkart_df = flipkart_df.set_index("uniq_id")

# %%
# view amazon dataset
amazon_df.head(2)
# Out:
#                                             crawl_timestamp  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
#
#                                                                         product_url  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  http://www.flipkart.com/alisha-solid-women-s-c...
# 7f7036a6d550aaa89d34c77bd39a5e48  http://www.flipkart.com/fabhomedecor-fabric-do...
#
#                                                          product_name  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
# 7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor Fabric Double Sofa Bed
#
#                                                               product_category_tree  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 7f7036a6d550aaa89d34c77bd39a5e48  ["Furniture >> Living Room Furniture >> Sofa B...
#
# ...

# %%
# view flipkart dataset
flipkart_df.head(2)
# Out:
#                                             crawl_timestamp  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  2016-03-25 22:59:23 +0000
# 7f7036a6d550aaa89d34c77bd39a5e48  2016-03-25 22:59:23 +0000
#
#                                                                         product_url  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  http://www.flipkart.com/alisha-solid-women-s-c...
# 7f7036a6d550aaa89d34c77bd39a5e48  http://www.flipkart.com/fabhomedecor-fabric-do...
#
#                                                          product_name  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  Alisha Solid Women's Cycling Shorts
# 7f7036a6d550aaa89d34c77bd39a5e48  FabHomeDecor Fabric Double Sofa Bed
#
#                                                               product_category_tree  \
# uniq_id
# c2d766ca982eca8304150849735ffef9  ["Clothing >> Women's Clothing >> Lingerie, Sl...
# 7f7036a6d550aaa89d34c77bd39a5e48  ["Furniture >> Living Room Furniture >> Sofa B...
#
# ...

# %%
# view shape of amazon dataset 
print(f"Amazon dataset contains Rows : {amazon_df.shape[0]}, Columns : {amazon_df.shape[1]}")
# Out:
# Amazon dataset contains Rows : 20000, Columns : 14

# %%
# view shape of flipkart dataset
print(f"Flipkart dataset contains Rows : {flipkart_df.shape[0]}, Columns : {flipkart_df.shape[1]}")
# Out:
# Flipkart dataset contains Rows : 20000, Columns : 14

# %%
# info 
amazon_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, c2d766ca982eca8304150849735ffef9 to cb4fa87a874f715fff567f7b7b3be79c
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   crawl_timestamp          20000 non-null  object
#  1   product_url              20000 non-null  object
#  2   product_name             20000 non-null  object
#  3   product_category_tree    20000 non-null  object
#  4   pid                      20000 non-null  object
#  5   retail_price             20000 non-null  int64
#  6   discounted_price         20000 non-null  int64
#  7   image                    19997 non-null  object
#  8   is_FK_Advantage_product  20000 non-null  bool
#  9   description              19998 non-null  object
#  10  product_rating           20000 non-null  object
#  11  overall_rating           20000 non-null  object
#  12  brand                    14136 non-null  object
# ...

# %%
# info 
flipkart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20000 entries, c2d766ca982eca8304150849735ffef9 to cb4fa87a874f715fff567f7b7b3be79c
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   crawl_timestamp          20000 non-null  object
#  1   product_url              20000 non-null  object
#  2   product_name             20000 non-null  object
#  3   product_category_tree    20000 non-null  object
#  4   pid                      20000 non-null  object
#  5   retail_price             19922 non-null  float64
#  6   discounted_price         19922 non-null  float64
#  7   image                    19997 non-null  object
#  8   is_FK_Advantage_product  20000 non-null  bool
#  9   description              19998 non-null  object
#  10  product_rating           20000 non-null  object
#  11  overall_rating           20000 non-null  object
#  12  brand                    14136 non-null  object
# ...

# %%
# statistics
amazon_df.describe().T
# Out:
#                     count        mean          std   min    25%    50%  \
# retail_price      20000.0  2957.09515  8993.993257 -20.0  647.0  999.0
# discounted_price  20000.0  2364.59705  8994.623680   0.0  424.0  663.0
#
#                      75%       max
# retail_price      1986.0  571223.0
# discounted_price  1235.0  726879.0

# %%
# statistics
flipkart_df.describe().T
# Out:
#                     count         mean          std   min    25%     50%  \
# retail_price      19922.0  2979.206104  9009.639341  35.0  666.0  1040.0
# discounted_price  19922.0  1973.401767  7333.586040  35.0  350.0   550.0
#
#                      75%       max
# retail_price      1999.0  571230.0
# discounted_price   999.0  571230.0
